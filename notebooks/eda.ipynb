# %% [markdown]
# ### Data overview

# %%
import os
import sys
import pandas as pd

# %%
current_dir = os.getcwd()
print(current_dir)

# Get the parent directory
parent_dir = os.path.dirname(current_dir)
print(parent_dir)

# Insert the path to the parent directory
sys.path.insert(0, parent_dir)

# # Insert the path to the Scripts directory
sys.path.insert(0, os.path.join(parent_dir, 'scripts'))

print(sys.path)
# Out:
# d:\10Academy-KAIM\week 3\kaim-week-3\notebooks
# d:\10Academy-KAIM\week 3\kaim-week-3
# ['d:\\10Academy-KAIM\\week 3\\kaim-week-3\\scripts', 'd:\\10Academy-KAIM\\week 3\\kaim-week-3', 'd:\\10Academy-KAIM\\week 3\\kaim-week-3\\notebooks', 'c:\\Program Files\\Python311\\python311.zip', 'c:\\Program Files\\Python311\\Lib', 'c:\\Program Files\\Python311\\DLLs', '', 'C:\\Users\\kulhab\\AppData\\Roaming\\Python\\Python311\\site-packages', 'c:\\Program Files\\Python311', 'c:\\Program Files\\Python311\\Lib\\site-packages']

# %%
# read in the python file
from scripts.eda import EDA
eda = EDA('../data/MachineLearningRating_v3.txt')

# %%
data = eda.fetch_data()
# Out:
# d:\10Academy-KAIM\week 3\kaim-week-3\scripts\eda.py:8: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(self.path, sep="|", on_bad_lines='skip')

# %%
# display all the available columns
pd.set_option('display.max_columns', None)
# Set option to display numbers in normal form (not scientific notation)
pd.set_option('display.float_format', '{:.6f}'.format)
data.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  MaritalStatus         Gender       Country Province  \
# ...

# %%
# Summary information
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %%
# Summary statistics
print(data.describe())
# Out:
#        UnderwrittenCoverID       PolicyID     PostalCode          mmcode  \
# count       1000098.000000 1000098.000000 1000098.000000   999546.000000
# mean         104817.546075    7956.682450    3020.600887 54877704.020474
# std           63293.708455    5290.038510    2649.854413 13603805.343562
# min               1.000000      14.000000       1.000000  4041200.000000
# 25%           55143.000000    4500.000000     827.000000 60056925.000000
# 50%           94083.000000    7071.000000    2000.000000 60058415.000000
# 75%          139190.000000   11077.000000    4180.000000 60058418.000000
# max          301175.000000   23246.000000    9870.000000 65065350.000000
#
#        RegistrationYear     Cylinders  cubiccapacity     kilowatts  \
# count    1000098.000000 999546.000000  999546.000000 999546.000000
# mean        2010.225371      4.046642    2466.743258     97.207919
# std            3.261391      0.294020     442.800640     19.393256
# ...

# %%
# Check for missing values
print(data.isna().sum())
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Histogram
plt.hist(data['UnderwrittenCoverID'], bins=30)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of UnderwrittenCoverID')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Histogram
plt.hist(data['PolicyID'], bins=30)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of PolicyID')
plt.show()

# %%
# Scatter plot
plt.scatter(data['TotalPremium'], data['TotalClaims'])
plt.xlabel('TotalPremium')
plt.ylabel('TotalClaims')
plt.title('Scatter Plot of Numerical Columns')
plt.show()
